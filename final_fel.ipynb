# %%
# Generic/Built-in
from typing import Callable, Generator, List, TypeVar, Tuple

# Libs
import time
import math
from tqdm.notebook import tqdm
import dask
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.checkpoint import checkpoint_sequential
import tntorch as tnt
import itertools
from tensorly.tenalg import tensor_dot

# Custom
from unet.unet import UNet
from autoencoder.cnnautoencoder_asym import AE
from preprocessing import LazyDataset, PatchedImage, PatchCoord
from imseg_wrapper import FedSeg

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
fedseg = FedSeg(
    unet_channels=3,
    unet_classes=3,
    image_height=8,
    image_width=4,
    patch_height=4,
    patch_width=4,
    tt_decomp_max_rank=3,
    tensor_batch_size=1000,
    AE=AE,
    AD=AE,
    unet=UNet
)

lazy_train = LazyDataset("data/stare/examples/stare/datasets/partition3/train")
lazy_test = LazyDataset("data/stare/examples/stare/datasets/partition3/evaluate")

lazy_train_dataloader = DataLoader(
    lazy_train, batch_size=4, collate_fn=lambda x: tuple(x)
)
lazy_test_dataloader = DataLoader(
    lazy_test, batch_size=4, collate_fn=lambda x: tuple(x)
)

# %%
# testing pytest

fedseg = FedSeg(
    unet_channels=3,
    unet_classes=3,
    image_height=9,
    image_width=9,
    patch_height=3,
    patch_width=3,
    AE=AE,
    AD=AE,
    unet=UNet,
)

fedseg.unet_input = 33

fedseg.create_adapter_layers()
tensor = torch.randint(0, 255, (1, 3, 3, 3)) / 255

encoder_logits = fedseg.autoencoder.forward(tensor)
print(encoder_logits.shape)
unet_logits = fedseg.unet(encoder_logits)
print(unet_logits.shape)
decoder_logits = fedseg.autodecoder(unet_logits)
# Out:
# Starting the encoder layers... Original input height is 3 and input width is 3
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 1, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 1, and the the difference is 2
# num convs: 0
#
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 2, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 2, and the the difference is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 1 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 8, cur image width: 8
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 6, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 6, and the the difference is 2
# Round 1 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 6, cur image width: 6
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 2 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 2 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 10, cur image width: 10
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 3 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 20, cur image width: 20
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 18, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 18, and the the difference is 2
# Round 3 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 18, cur image width: 18
# Finished ConvTranspose2D layers...
#
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:20, image_width:20
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:22, image_width:22
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:24, image_width:24
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:26, image_width:26
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:28, image_width:28
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:30, image_width:30
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:32, image_width:32
# Continuing decoder layers by adding + 1 layers
# Size after +1 conv2d:33
# Starting the encoder layers... Original input height is 33 and input width is 33
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 31, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 31, and the the difference is 2
# Round 0 - Count 1: cur image height: 31, cur image width: 31
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 29, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 29, and the the difference is 2
# Round 0 - Count 2: cur image height: 29, cur image width: 29
# Round 0 - Count 2: cur image height: 14, cur image width: 14
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 12, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 12, and the the difference is 2
# Round 1 - Count 1: cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 1 - Count 2: cur image height: 10, cur image width: 10
# Round 1 - Count 2: cur image height: 5, cur image width: 5
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# num convs: 1
#
# Continuing encoder layers after maxpooling layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# Round 0: cur image height: 3, cur image width: 3
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Finished ConvTranspose2D layers...
#
# Continuing decoder layers by adding + 1 layers
# Size after +1 conv2d:3
# torch.Size([1, 3, 33, 33])
# torch.Size([1, 3, 33, 33])

# %%
from torchsummary import summary

autoencoder = AE(
    input_height=91,
    input_width=91,
    encoded_size=3,
    decoded_size=37,
    in_channels=3,
    out_channels=3,
    num_output_features=3,
    kernel_size=(5, 5),
)

summary(autoencoder, (3,91,91))
# Out:
# Starting the encoder layers... Original input height is 91 and input width is 91
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 87, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 87, and the the difference is 4
# Round 0 - Count 1: cur image height: 87, cur image width: 87
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 83, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 83, and the the difference is 4
# Round 0 - Count 2: cur image height: 83, cur image width: 83
# Round 0 - Count 2: cur image height: 41, cur image width: 41
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 37, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 37, and the the difference is 4
# Round 1 - Count 1: cur image height: 37, cur image width: 37
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 33, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 33, and the the difference is 4
# Round 1 - Count 2: cur image height: 33, cur image width: 33
# Round 1 - Count 2: cur image height: 16, cur image width: 16
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 12, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 12, and the the difference is 4
# Round 2 - Count 1: cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 8, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 8, and the the difference is 4
# Round 2 - Count 2: cur image height: 8, cur image width: 8
# Round 2 - Count 2: cur image height: 4, cur image width: 4
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 0, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 0, and the the difference is 4
# num convs: 0
#
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 3, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 3, and the the difference is 1
# Round 0: cur image height: 3, cur image width: 3
#
# Starting the decoder layers... input height to decoder layers is 3 and input width is 3
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 6, cur image width: 6
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 2, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 2, and the the difference is 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 2, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 2, and the the difference is 4
# Round 0 - Count 1: Cur image sizes after Conv2D downsampling- cur image height: 2, cur image width: 2
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 1 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is 0, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is 0, and the the difference is 4
# Round 1 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 0, cur image width: 0
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 2 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 0, cur image width: 0
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -4, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -4, and the the difference is 4
# Round 2 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -4, cur image width: -4
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 3 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -8, cur image width: -8
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -12, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -12, and the the difference is 4
# Round 3 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -12, cur image width: -12
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 4 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -24, cur image width: -24
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -28, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -28, and the the difference is 4
# Round 4 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -28, cur image width: -28
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 5 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -56, cur image width: -56
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -60, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -60, and the the difference is 4
# Round 5 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -60, cur image width: -60
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 6 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -120, cur image width: -120
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -124, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -124, and the the difference is 4
# Round 6 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -124, cur image width: -124
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 7 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -248, cur image width: -248
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -252, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -252, and the the difference is 4
# Round 7 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -252, cur image width: -252
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 8 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -504, cur image width: -504
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -508, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -508, and the the difference is 4
# Round 8 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -508, cur image width: -508
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 9 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -1016, cur image width: -1016
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -1020, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -1020, and the the difference is 4
# Round 9 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -1020, cur image width: -1020
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 10 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -2040, cur image width: -2040
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -2044, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -2044, and the the difference is 4
# Round 10 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -2044, cur image width: -2044
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 11 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -4088, cur image width: -4088
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -4092, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -4092, and the the difference is 4
# Round 11 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -4092, cur image width: -4092
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 12 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -8184, cur image width: -8184
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -8188, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -8188, and the the difference is 4
# Round 12 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -8188, cur image width: -8188
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 13 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -16376, cur image width: -16376
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -16380, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -16380, and the the difference is 4
# Round 13 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -16380, cur image width: -16380
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 14 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -32760, cur image width: -32760
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -32764, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -32764, and the the difference is 4
# Round 14 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -32764, cur image width: -32764
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 15 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -65528, cur image width: -65528
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -65532, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -65532, and the the difference is 4
# Round 15 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -65532, cur image width: -65532
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 16 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -131064, cur image width: -131064
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -131068, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -131068, and the the difference is 4
# Round 16 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -131068, cur image width: -131068
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 17 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -262136, cur image width: -262136
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -262140, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -262140, and the the difference is 4
# Round 17 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -262140, cur image width: -262140
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 18 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -524280, cur image width: -524280
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -524284, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -524284, and the the difference is 4
# Round 18 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -524284, cur image width: -524284
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 19 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -1048568, cur image width: -1048568
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -1048572, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -1048572, and the the difference is 4
# Round 19 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -1048572, cur image width: -1048572
# Starting decoder ConvTranspose2D layers...Image height: 3, Input width;3
# Round 20 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: -2097144, cur image width: -2097144
# For height, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output height is -2097148, and the difference is 4
# For width, with padding: 0, dilation: 1, kernel_size[0]: 5, and stride:1, the output width is -2097148, and the the difference is 4
# Round 20 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: -
ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> )
#      <a href='vscode-notebook-cell:/Users/felicia/Desktop/aiap/fedseg/final_fel.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> summary(autoencoder, (3,91,91))
#
# File ~/Desktop/aiap/fedseg/autoencoder/cnnautoencoder_asym.py:762, in AE.__init__(self, input_height, input_width, encoded_size, decoded_size, in_channels, out_channels, num_output_features, kernel_size, upsample_kernel_size, stride, upsample_stride, padding, padding_mode, output_padding, dilation, groups, bias)
#     745 self.bias = bias
#     747 self.encoder = self.generate_encoder_layers(
#     748     input_height=self.input_height,
#     749     input_width = self.input_width,
#    (...)
#     759     bias=self.bias,
#     760 )
# --> 762 self.decoder = self.generate_decoder_layers(
#     763     input_height=self.encoded_size,
#     764     input_width = self.encoded_size,
#     765     decoded_size=self.decoded_size,
#     766     in_channels=self.in_channels,
#     767     out_channels=self.out_channels,
#     768     num_output_features=self.num_output_features,
#     769     kernel_size=self.kernel_size,
#     770     upsample_kernel_size=self.upsample_kernel_size,
#     771     stride=self.stride,
#     772     upsample_stride=self.upsample_stride,
#     773     padding=self.padding,
#     774     padding_mode=self.padding_mode,
#     775     output_padding=self.output_padding,
#     776     dilation=self.dilation,
#     777     groups=self.groups,
#     778     bias=self.bias,
#     779 )
#
# File ~/Desktop/aiap/fedseg/autoencoder/cnnautoencoder_asym.py:563, in AE.generate_decoder_layers(self, input_height, input_width, decoded_size, in_channels, out_channels, num_output_features, kernel_size, upsample_kernel_size, stride, upsample_stride, padding, output_padding, padding_mode, dilation, groups, bias)
#     548 if (cur_image_height - height_reduction) * 2 != cur_image_height:
#     549     layers.add_module(
#     550         f"UpsampleConv{round}-{count}",
#     551         nn.Conv2d(
#    (...)
#     561         ),
#     562     )
# --> 563     cur_image_height,cur_image_width = self.calc_size(
#     564         input_height=cur_image_height,
#     565         input_width=cur_image_width,
#     566         padding=padding,
#     567         dilation=dilation,
#     568         kernel_size=kernel_size,
#     569         stride=stride,
#     570     )
#     571     # print(f"Size after conv2d:{cur_image_size} ")
#     572     print(f"Round {round} - Count {count}: Cur image sizes after Conv2D downsampling - cur image height: {cur_image_height}, cur image width: {cur_image_width}")
#
# File ~/Desktop/aiap/fedseg/autoencoder/cnnautoencoder_asym.py:18, in AE.calc_size(self, input_height, input_width, padding, dilation, kernel_size, stride, return_diff)
#      13 def calc_size(
#      14     self, input_height,input_width, padding, dilation, kernel_size, stride, return_diff=False
#      15 ):
#      16     # assumes a square image, therefore height = width
#      17     output_height = floor(
# ---> 18         (input_height + (2 * padding) - dilation * (kernel_size[0] - 1) - 1) / stride
#      19         + 1
#      20     )
#      22     output_width = floor(
#      23         (input_width + (2 * padding) - dilation * (kernel_size[1] - 1) - 1) / stride
#      24         + 1
#      25     )
#      27     height_diff = input_height - output_height
#
# OverflowError: integer division result too large for a float

# %%
# forward an image
image, mask = next(fedseg.images(lazy_train_dataloader))
image.load()
new_image = fedseg.forward(image)
# Out:
# Generating patches...
#
# PATCH:torch.Size([4, 4, 3])
# Flattening patch...
# Calculating local maps...
# Calculating global maps...
# Converting global map to TT...
# Padding tensors......
# Forward pass...
# Starting the encoder layers... Original input height is 3 and input width is 3
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 1, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 1, and the the difference is 2
# num convs: 0
#
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 2, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 2, and the the difference is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 1 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 8, cur image width: 8
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 6, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 6, and the the difference is 2
# Round 1 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 6, cur image width: 6
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 2 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 2 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 10, cur image width: 10
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 3 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 20, cur image width: 20
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 18, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 18, and the the difference is 2
# Round 3 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 18, cur image width: 18
# Finished ConvTranspose2D layers...
#
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:20, image_width:20
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:22, image_width:22
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:24, image_width:24
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:26, image_width:26
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:28, image_width:28
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:30, image_width:30
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:32, image_width:32
# Starting the encoder layers... Original input height is 32 and input width is 32
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 30, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 30, and the the difference is 2
# Round 0 - Count 1: cur image height: 30, cur image width: 30
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 28, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 28, and the the difference is 2
# Round 0 - Count 2: cur image height: 28, cur image width: 28
# Round 0 - Count 2: cur image height: 14, cur image width: 14
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 12, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 12, and the the difference is 2
# Round 1 - Count 1: cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 1 - Count 2: cur image height: 10, cur image width: 10
# Round 1 - Count 2: cur image height: 5, cur image width: 5
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# num convs: 1
#
# Continuing encoder layers after maxpooling layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# Round 0: cur image height: 3, cur image width: 3
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 2, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 2, and the the difference is 2
# Finished ConvTranspose2D layers...
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:212: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:396: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:403: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# TENSOR COUNT:  10
# TENSOR COUNT:  20
# TENSOR COUNT:  30
# TENSOR COUNT:  40
# TENSOR COUNT:  50
# stacked tensor shape:torch.Size([3, 4, 4])
# forwarded tensor shape:torch.Size([4, 4, 3])
# stacked_tensor.shape:  torch.Size([4, 4, 3])
# patch counter: 1
# PATCH:torch.Size([4, 4, 3])
# Flattening patch...
# Calculating local maps...
# Calculating global maps...
# Converting global map to TT...
# Padding tensors......
# Forward pass...
# TENSOR COUNT:  10
# TENSOR COUNT:  20
# TENSOR COUNT:  30
# TENSOR COUNT:  40
# TENSOR COUNT:  50
# stacked tensor shape:torch.Size([3, 4, 4])
# forwarded tensor shape:torch.Size([4, 4, 3])
# stacked_tensor.shape:  torch.Size([4, 4, 3])
# patch counter: 2
# number of patches 2
# shape of final patch image torch.Size([8, 4, 3])

# %% [markdown]
# ## Training Loop

# %%
def pixel_accuracy(output, mask):
    print(f"pixel input mask shape:{mask.shape}")
    print(f"pixel input output shape:{output.shape}")
    with torch.no_grad():
        print(f"softmax results: {F.softmax(output, dim=1).shape}")
        output = torch.argmax(F.softmax(output, dim=1), dim=0)
        print(f"pixel mask shape:{mask.shape}")
        print(f"pixel output shape:{output.shape}")
        correct = torch.eq(output, mask).int()
        accuracy = float(correct.sum()) / float(correct.numel())
    return accuracy

# %%
def mIoU(pred_mask, mask, smooth=1e-10, n_classes=2):
    with torch.no_grad():
        pred_mask = F.softmax(pred_mask, dim=1)
        pred_mask = torch.argmax(pred_mask, dim=1)
        pred_mask = pred_mask.contiguous().view(-1)
        mask = mask.contiguous().view(-1)

        iou_per_class = []
        for clas in range(0, n_classes):  # loop per pixel class
            true_class = pred_mask == clas
            true_label = mask == clas

            if true_label.long().sum().item() == 0:  # no exist label in this loop
                iou_per_class.append(np.nan)
            else:
                print(true_class.shape)
                print(true_label.shape)
                intersect = (
                    torch.logical_and(true_class, true_label).sum().float().item()
                )
                union = torch.logical_or(true_class, true_label).sum().float().item()

                iou = (intersect + smooth) / (union + smooth)
                iou_per_class.append(iou)
        return np.nanmean(iou_per_class)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def fit(
    epochs,
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    scheduler,
    patch=False,
):
    torch.cuda.empty_cache()
    train_losses = []
    test_losses = []
    val_iou = []
    val_acc = []
    train_iou = []
    train_acc = []
    # lrs = []
    min_loss = np.inf
    decrease = 1
    not_improve = 0

    model
    fit_time = time.time()
    for e in range(epochs):
        since = time.time()
        running_loss = 0
        iou_score = 0
        accuracy = 0
        # training loop
        model.train()
        for i, data in enumerate(tqdm(fedseg.images(train_loader))):
            # img is in the format[C,H,W]
            image, mask = data
            output = model(image)
            mask_array = mask.retrieve(PatchCoord(0, 0), PatchCoord(700, 605))
            chw_output = torch.permute(output, (2, 0, 1))
            # because the mask is of type torch.ByteTensor, we have to cast it to float
            mask_long = mask_array.long()

            loss = criterion(chw_output.to(device), mask_long.to(device))  # to fix this

            # evaluation metrics

            accuracy += pixel_accuracy(output, mask)
            print(f"accuracy: {accuracy}")
            # backward
            loss.backward()
            optimizer.step()  # update weight
            optimizer.zero_grad()  # reset gradient

            # step the learning rate
            scheduler.step()

            running_loss += loss.item()
            torch.save(
                {
                    "epoch": e,
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "loss": loss,
                },
                f"model_epoch{e}.pt",
            )
        else:
            print("Evaluating...")
            model.eval()
            test_loss = 0
            test_accuracy = 0
            val_iou_score = 0
            # validation loop
            with torch.no_grad():

                for i, data in enumerate(tqdm(fedseg.images(val_loader))):
                    # img is in the format[C,H,W]
                    image, mask = data
                    image.load()
                    output = model(image)
                    print("output image shape", image.shape)
                    mask_array = mask.retrieve(
                        PatchCoord(0, 0), PatchCoord(4, 8)
                    )  # W, H
                    chw_output = torch.permute(output, (2, 0, 1)) 
                    # because the mask is of type torch.ByteTensor, we have to cast it to float
                    mask_long = mask_array.long()

                    # evaluation metrics
                    # val_iou_score +=  mIoU(output, mask)
                    print(f"test accuracy output shape:{output.shape}")
                    print(f"test accuracy mask shape:{mask.shape}")
                    test_accuracy += pixel_accuracy(output, mask)
                    # loss
                    loss = criterion(output, mask)
                    test_loss += loss.item()

            # calculatio mean for each batch
            train_losses.append(running_loss / len(train_loader))
            test_losses.append(test_loss / len(val_loader))

            if min_loss > (test_loss / len(val_loader)):
                print(
                    "Loss Decreasing.. {:.3f} >> {:.3f} ".format(
                        min_loss, (test_loss / len(val_loader))
                    )
                )
                min_loss = test_loss / len(val_loader)
                decrease += 1
                if decrease % 5 == 0:
                    print("saving model...")
                    # torch.save(model, 'Unet-Mobilenet_v2_mIoU-{:.3f}.pt'.format(val_iou_score/len(val_loader)))

            if (test_loss / len(val_loader)) > min_loss:
                not_improve += 1
                min_loss = test_loss / len(val_loader)
                print(f"Loss Not Decrease for {not_improve} time")
                if not_improve == 7:
                    print("Loss not decrease for 7 times, Stop Training")
                    break

            train_acc.append(accuracy / len(train_loader))
            val_acc.append(test_accuracy / len(val_loader))
            print(
                "Epoch:{}/{}..".format(e + 1, epochs),
                "Train Loss: {:.3f}..".format(running_loss / len(train_loader)),
                "Val Loss: {:.3f}..".format(test_loss / len(val_loader)),
                "Train Acc:{:.3f}..".format(accuracy / len(train_loader)),
                "Val Acc:{:.3f}..".format(test_accuracy / len(val_loader)),
                "Time: {:.2f}m".format((time.time() - since) / 60),
            )

    history = {
        "train_loss": train_losses,
        "val_loss": test_losses,
        "train_acc": train_acc,
        "val_acc": val_acc,
    }
    print("Total time: {:.2f} m".format((time.time() - fit_time) / 60))
    return history

# %%
max_lr = 1e-3
epoch = 3
weight_decay = 1e-4
# torch.backends.cudnn.benchmark = True
# torch.backends.cudnn.enabled = True
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(fedseg.parameters(), lr=max_lr, weight_decay=weight_decay)
sched = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr, epochs=epoch, steps_per_epoch=len(lazy_train_dataloader)
)

history = fit(
    epoch,
    fedseg,
    lazy_train_dataloader,
    lazy_test_dataloader,
    criterion,
    optimizer,
    sched,
)
# Out:
# 0it [00:00, ?it/s]
# Generating patches...
#
# PATCH:torch.Size([4, 4, 3])
# Flattening patch...
# Calculating local maps...
# Calculating global maps...
# Converting global map to TT...
# Padding tensors......
# Forward pass...
# Starting the encoder layers... Original input height is 3 and input width is 3
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 1, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 1, and the the difference is 2
# num convs: 0
#
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 2, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 2, and the the difference is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 1 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 8, cur image width: 8
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 6, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 6, and the the difference is 2
# Round 1 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 6, cur image width: 6
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 2 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 2 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 10, cur image width: 10
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 3 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 20, cur image width: 20
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 18, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 18, and the the difference is 2
# Round 3 - Count 1: Cur image sizes after Conv2D downsampling - cur image height: 18, cur image width: 18
# Finished ConvTranspose2D layers...
#
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:20, image_width:20
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:22, image_width:22
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:24, image_width:24
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:26, image_width:26
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:28, image_width:28
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:30, image_width:30
# Continuing decoder layers after ConvTranspose2D layers...
# Image sizes after +2 conv2d layers - image height:32, image_width:32
# Starting the encoder layers... Original input height is 32 and input width is 32
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 30, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 30, and the the difference is 2
# Round 0 - Count 1: cur image height: 30, cur image width: 30
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 28, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 28, and the the difference is 2
# Round 0 - Count 2: cur image height: 28, cur image width: 28
# Round 0 - Count 2: cur image height: 14, cur image width: 14
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 12, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 12, and the the difference is 2
# Round 1 - Count 1: cur image height: 12, cur image width: 12
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 10, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 10, and the the difference is 2
# Round 1 - Count 2: cur image height: 10, cur image width: 10
# Round 1 - Count 2: cur image height: 5, cur image width: 5
# Finished adding max pool layers
#
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# num convs: 1
#
# Continuing encoder layers after maxpooling layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 3, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 3, and the the difference is 2
# Round 0: cur image height: 3, cur image width: 3
# Amt height to force shrink: 1
#
# Continuing encoder layers... -1 image shrinking layers...
# For height, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output height is 2, and the difference is 1
# For width, with padding: 0, dilation: 1, kernel_size[0]: 2, and stride:1, the output width is 2, and the the difference is 1
# Round 0: cur image height: 2, cur image width: 2
#
# Starting the decoder layers... input height to decoder layers is 2 and input width is 2
# Starting decoder ConvTranspose2D layers...Image height: 2, Input width;2
# Round 0 - Count 1: Cur image sizes after ConvTranspose2D - cur image height: 4, cur image width: 4
# For height, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output height is 2, and the difference is 2
# For width, with padding: 0, dilation: 1, kernel_size[0]: 3, and stride:1, the output width is 2, and the the difference is 2
# Finished ConvTranspose2D layers...
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:175: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:359: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/felicia_wxp/anaconda3/envs/fedseg1/lib/python3.7/site-packages/ipykernel_launcher.py:366: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# TENSOR COUNT:  10
# TENSOR COUNT:  20
# TENSOR COUNT:  30
# TENSOR COUNT:  40
# TENSOR COUNT:  50
# stacked tensor shape:torch.Size([3, 4, 4])
# forwarded tensor shape:torch.Size([4, 4, 3])
# stacked_tensor.shape:  torch.Size([4, 4, 3])
# patch counter: 1
# PATCH:torch.Size([4, 4, 3])
# Flattening patch...
# Calculating local maps...
# Calculating global maps...
# Converting global map to TT...
# Padding tensors......
# Forward pass...
# TENSOR COUNT:  10
# TENSOR COUNT:  20
# TENSOR COUNT:  30
# TENSOR COUNT:  40
# TENSOR COUNT:  50
# stacked tensor shape:torch.Size([3, 4, 4])
# forwarded tensor shape:torch.Size([4, 4, 3])
# stacked_tensor.shape:  torch.Size([4, 4, 3])
# patch counter: 2
# number of patches 2
# 2
# 1
# shape of final patch image torch.Size([8, 4, 3])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_572650/2587676759.py in <module>
#      18     criterion,
#      19     optimizer,
# ---> 20     sched,
#      21 )
#
# /tmp/ipykernel_572650/3476244045.py in fit(epochs, model, train_loader, val_loader, criterion, optimizer, scheduler, patch)
#      41             mask_long = mask_array.long()
#      42
# ---> 43             loss = criterion(chw_output.to(device), mask_long.to(device))
#      44
#      45             # evaluation metrics
#
# ~/anaconda3/envs/fedseg1/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/fedseg1/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1164         return F.cross_entropy(input, target, weight=self.weight,
#    1165                                ignore_index=self.ignore_index, reduction=self.reduction,
# -> 1166                                label_smoothing=self.label_smoothing)
#    1167
#    1168
#
# ~/anaconda3/envs/fedseg1/lib/python3.7/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3012     if size_average is not None or reduce is not None:
#    3013         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3014     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#    3015
#    3016
#
# ValueError: Expected input batch_size (3) to match target batch_size (1).

# %% [markdown]
# TO DO:
#
# - to fix self.image_height = image_height
# - to get mask from PatchedImage
# - to test out py file
# - to do unit test
